# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Jxbh0mAHd0jlhrllGGkf")
project = rf.workspace("nepri").project("protist")
dataset = project.version(2).download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.235, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Protist-2 in yolov8:: 100%|██████████| 1299/1299 [00:00<00:00, 2466.07it/s]

# %%
import torch
torch.cuda.empty_cache()#release all the gpu memory

# %%
# !yolo task=detect mode=train model=yolov8s.pt data="C:\\Users\\hanba\\OneDrive - Lund University\\Skrivbordet\\Deeplearning\\Yolov8\\Protist-1/data.yaml" epochs=100 imgsz=640 plots=True
# Out:
# New https://pypi.org/project/ultralytics/8.1.16 available ðŸ˜ƒ Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.235 ðŸš€ Python-3.8.18 torch-2.1.2 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# ...

# %% [markdown]
# ## Upload weight

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"C:\\Users\\hanba\\OneDrive - Lund University\\Skrivbordet\\Deeplearning\\Yolov8\\runs/detect/train15/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.0.235, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n:  y
# View the status of your deployment at: https://app.roboflow.com/nepri/protist/2

# %%
Dependency ultralytics==8.0.196

# %%
from ultralytics import YOLO
import tkinter as tk
from tkinter import filedialog
def select_file():
    """
    Opens a window to select a file and returns the selected file path.
    """
    root = tk.Tk()
    root.withdraw()  # Hide the main window
    file_path = filedialog.askopenfilename()  # Show the file selection dialog
    return file_path
# Load a pretrained YOLOv8n model
model = YOLO(r'C:\Users\hanba\OneDrive - Lund University\Skrivbordet\Deeplearning\Yolov8\model_- 8 january 2024 9_53.pt')

# Define path to the image file
source = select_file()

# Run inference on the source
results = model(source)  # list of Results objects

# %%
metrics = model.val(split='test')
